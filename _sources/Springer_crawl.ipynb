# %% [markdown]
# # Crawling Springer

# %%
pip install sprynger
# Out:
# Collecting sprynger
#   Downloading sprynger-0.4.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sprynger) (5.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from sprynger) (2.32.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from sprynger) (2.5.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from sprynger) (4.3.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->sprynger) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->sprynger) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->sprynger) (2025.8.3)
# Downloading sprynger-0.4.1-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: sprynger
# Successfully installed sprynger-0.4.1

# %% [markdown]
# Crawling menggunakan keyword "web mining"

# %%
import requests
import csv
from datetime import datetime
import pandas as pd

# Silahkan membuat api key dari https://dev.springernature.com/#api
api_key = "8bd578e4f19c2e9b1397f546bf3a9aa8"
keyword = "web mining"  # Ganti dengan kata kunci yang diinginkan

url = "https://api.springernature.com/meta/v2/json"
params = {
    "q": keyword,  # Menggunakan kata kunci langsung
    "api_key": api_key,
    "p": 10  # Jumlah hasil yang ingin ditampilkan
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    print(f"Total hasil: {data['result'][0]['total']}\n")

    # List untuk menyimpan semua data
    all_records = []

    for i, record in enumerate(data['records'], 1):
        doi = record.get('doi', 'N/A')
        title = record.get('title', 'No title')
        abstract = record.get('abstract', 'No abstract')
        publication_date = record.get('publicationDate', 'N/A')
        content_type = record.get('contentType', 'N/A')
        publisher = record.get('publisher', 'N/A')

        # Extract authors
        authors = []
        if 'creators' in record:
            for creator in record['creators']:
                authors.append(creator.get('creator', 'N/A'))

        # Extract URL jika ada
        url_value = 'N/A'
        if 'url' in record and record['url']:
            url_value = record['url'][0].get('value', 'N/A')

        # Simpan data ke dictionary
        record_data = {
            'no': i,
            'doi': doi,
            'title': title,
            'publication_date': publication_date,
            'content_type': content_type,
            'publisher': publisher,
            'authors': '; '.join(authors),
            'abstract': abstract,
            'url': url_value
        }
        all_records.append(record_data)

        # Print ke console
        print(f"Result {i}:")
        print(f"DOI: {doi}")
        print(f"Title: {title}")
        print(f"Publication Date: {publication_date}")
        print(f"Content Type: {content_type}")
        print(f"Authors: {', '.join(authors)}")
        print(f"Abstract: {abstract[:300]}...")  # Batasi abstract untuk readability
        print("-" * 80 + "\n")

    # Simpan ke CSV menggunakan pandas
    try:
        # Buat DataFrame
        df = pd.DataFrame(all_records)

        # Generate filename dengan timestamp
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f"springer_{keyword.replace(' ', '_')}_{timestamp}.csv"

        # Simpan ke CSV
        df.to_csv(filename, index=False, encoding='utf-8')
        print(f"✅ Data berhasil disimpan ke: {filename}")
        print(f"📊 Jumlah record yang disimpan: {len(all_records)}")

    except Exception as e:
        print(f"❌ Error saat menyimpan CSV: {e}")

else:
    print("Error:", response.status_code, response.text)
# Out:
# Total hasil: 317019
#
# Result 1:
# DOI: 10.1007/978-3-032-00983-8_5
# Title: Survey on Data Mining and Machine Learning Methods Used in Analyzing Tweets
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Sadasivuni, Sudha Tushara, Sadasivuni, Sudarsan
# Abstract: It is observed that the Mental illness by the actions and individual emotions and expressions towards a particular situation. It indicates that American Psychiatric Association that has 19% of people experience mental illness. Nearly 4.1% of people [ 1 ] are seriously affected by mental illness. In ...
# --------------------------------------------------------------------------------
#
# Result 2:
# DOI: 10.1007/978-3-031-93802-3_7
# Title: Unveiling Power Laws in Graph Mining: Techniques and Applications in Graph Query Analysis
# Publication Date: 2026-01-01
# Content Type: Chapter
# Authors: Adiyattil, Rini, Thangamayan, S., Aswathy Prakash, G.
# Abstract: Power laws play a crucial role in understanding the structural and functional properties of real-world graphs, influencing various aspects of graph mining and query processing. This paper explores the prevalence of power-law distributions in large-scale graph structures and their implications for gr...
# --------------------------------------------------------------------------------
#
# Result 3:
# DOI: 10.1007/978-981-96-7238-7_2
# Title: Architecture Mining Approach for Systems-of-Systems: Monitoring and Discovery
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Chaabane, Mariam, Rodriguez, Ismael Bouassida
# Abstract: Context: Systems of Systems (SoS) constitute a type of complex software systems resulting from integrating heterogeneous constituent systems that are independently operable on their own but are networked together for a common goal. Each constituent system has its own purpose and could operate and co...
# --------------------------------------------------------------------------------
#
# Result 4:
# DOI: 10.1007/978-3-031-95296-8_15
# Title: A Mathematical Model and Algorithm for Data Analysis in the Intelligent Management System for Mining and Transport Complexes
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Kalandarov, Ilyos, Muminov, Bahodir, Davlatov, Bahodir
# Abstract: Machine learning methods play an important role in creating algorithms for data analysis in the mining industry. These methods allow you to train the system based on historical data and identify hidden patterns that may not be obvious in traditional analysis. Machine learning algorithms can be used ...
# --------------------------------------------------------------------------------
#
# Result 5:
# DOI: 10.1007/978-3-031-90470-7_6
# Title: ‘Internet of Things’ and ‘Social Networking’: Containment
# Publication Date: 2026-01-01
# Content Type: Chapter
# Authors: Gupta, Suman
# Abstract: Moving to the post-2000 period, or the post-formation Internet Polity, this chapter begins with the implications of the internet becoming the centred repository of sources, medium of investigation, and object in historicist accounts of recent and contemporary events. Debates on ‘technological determ...
# --------------------------------------------------------------------------------
#
# Result 6:
# DOI: 10.1007/978-3-031-93802-3_10
# Title: Integrating Graph Convolutional Networks for Web Traffic Prediction
# Publication Date: 2026-01-01
# Content Type: Chapter
# Authors: Dewangan, Deepak Kumar
# Abstract: Web traffic forecasting plays a crucial role in optimizing network resources, enhancing user experience, and ensuring efficient server load management. Traditional approaches, such as ARIMA, SARIMA, and machine learning methods like support vector machines and decision trees, focus primarily on temp...
# --------------------------------------------------------------------------------
#
# Result 7:
# DOI: 10.1007/978-3-031-93257-1_6
# Title: Adaptive Web API Recommendation via Matching Service Clusters and Mashup Requirement
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Zhu, Yue, Zou, Guobing, Yang, Song, Hu, Shengxiang, Li, Pengtao, Zeng, Chunhua
# Abstract: With the rapid proliferation of Web services and Web APIs, recommendation systems can effectively address the issue of information overload and alleviate the burden of meaningless filtering. Existing approaches can help filtering appropriate Web services for mashup creation, however, they often fall...
# --------------------------------------------------------------------------------
#
# Result 8:
# DOI: 10.1007/978-3-032-02215-8_3
# Title: Leveraging Machine Learning Techniques for Customer Data Deduplication - Hard-Won Lessons from a Real-World Project in the Financial Industry
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Wrembel, Robert, Andrzejewski, Witold, Boiński, Pawel, Bębel, Bartosz
# Abstract: This paper is associated with a tutorial presented at DEXA 2025 Conferences and Workshops. The tutorial shares the practical experience gained from a 3-year R&D project for a big financial institution in Poland. The project aimed at developing deduplication pipelines for customer records. It involve...
# --------------------------------------------------------------------------------
#
# Result 9:
# DOI: 10.1007/978-3-031-95296-8_21
# Title: Intelligent Control System for Ore Transportation and Grinding Process in Gold Mining Fields
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Asadova, Mohlaroyim, Kalandarov, Ilyos, Kakhorov, Azamat
# Abstract: This paper is devoted to optimizing the processes of work using intellectual control systems for the transportation and grinding of ore in gold mining fields. Ore is being optimized through the introduction of modern technologies and information systems in the transportation and grinding processes i...
# --------------------------------------------------------------------------------
#
# Result 10:
# DOI: 10.1007/978-3-032-02088-8_29
# Title: Benchmarking Embedding Techniques for Modeling User Navigation Behavior on Task-Oriented Software
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Boukharouba, Ikram, Sèdes, Florence, Verhaeghe, Benoit, Bortolaso, Christophe
# Abstract: Understanding user navigation patterns from clickstream data is crucial for improving business software, yet remains challenging due to the complexity and variability of real-world environments. Unlike controlled settings, real-world clickstreams are noisy, fragmented, and often incomplete, due to s...
# --------------------------------------------------------------------------------
#
# ✅ Data berhasil disimpan ke: springer_web_mining_20250828_071353.csv
# 📊 Jumlah record yang disimpan: 10

# %% [markdown]
# Crawling menggunakan keyword "web usage mining"

# %%
import requests
import csv
from datetime import datetime
import pandas as pd

# Silahkan membuat api key dari https://dev.springernature.com/#api
api_key = "8bd578e4f19c2e9b1397f546bf3a9aa8"
keyword = "web usage mining"  # Ganti dengan kata kunci yang diinginkan

url = "https://api.springernature.com/meta/v2/json"
params = {
    "q": keyword,  # Menggunakan kata kunci langsung
    "api_key": api_key,
    "p": 10  # Jumlah hasil yang ingin ditampilkan
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    print(f"Total hasil: {data['result'][0]['total']}\n")

    # List untuk menyimpan semua data
    all_records = []

    for i, record in enumerate(data['records'], 1):
        doi = record.get('doi', 'N/A')
        title = record.get('title', 'No title')
        abstract = record.get('abstract', 'No abstract')
        publication_date = record.get('publicationDate', 'N/A')
        content_type = record.get('contentType', 'N/A')
        publisher = record.get('publisher', 'N/A')

        # Extract authors
        authors = []
        if 'creators' in record:
            for creator in record['creators']:
                authors.append(creator.get('creator', 'N/A'))

        # Extract URL jika ada
        url_value = 'N/A'
        if 'url' in record and record['url']:
            url_value = record['url'][0].get('value', 'N/A')

        # Simpan data ke dictionary
        record_data = {
            'no': i,
            'doi': doi,
            'title': title,
            'publication_date': publication_date,
            'content_type': content_type,
            'publisher': publisher,
            'authors': '; '.join(authors),
            'abstract': abstract,
            'url': url_value
        }
        all_records.append(record_data)

        # Print ke console
        print(f"Result {i}:")
        print(f"DOI: {doi}")
        print(f"Title: {title}")
        print(f"Publication Date: {publication_date}")
        print(f"Content Type: {content_type}")
        print(f"Authors: {', '.join(authors)}")
        print(f"Abstract: {abstract[:300]}...")  # Batasi abstract untuk readability
        print("-" * 80 + "\n")

    # Simpan ke CSV menggunakan pandas
    try:
        # Buat DataFrame
        df = pd.DataFrame(all_records)

        # Generate filename dengan timestamp
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f"springer_{keyword.replace(' ', '_')}_{timestamp}.csv"

        # Simpan ke CSV
        df.to_csv(filename, index=False, encoding='utf-8')
        print(f"✅ Data berhasil disimpan ke: {filename}")
        print(f"📊 Jumlah record yang disimpan: {len(all_records)}")

    except Exception as e:
        print(f"❌ Error saat menyimpan CSV: {e}")

else:
    print("Error:", response.status_code, response.text)
# Out:
# Total hasil: 90635
#
# Result 1:
# DOI: 10.1007/978-3-031-90470-7_6
# Title: ‘Internet of Things’ and ‘Social Networking’: Containment
# Publication Date: 2026-01-01
# Content Type: Chapter
# Authors: Gupta, Suman
# Abstract: Moving to the post-2000 period, or the post-formation Internet Polity, this chapter begins with the implications of the internet becoming the centred repository of sources, medium of investigation, and object in historicist accounts of recent and contemporary events. Debates on ‘technological determ...
# --------------------------------------------------------------------------------
#
# Result 2:
# DOI: 10.1007/978-3-032-00983-8_5
# Title: Survey on Data Mining and Machine Learning Methods Used in Analyzing Tweets
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Sadasivuni, Sudha Tushara, Sadasivuni, Sudarsan
# Abstract: It is observed that the Mental illness by the actions and individual emotions and expressions towards a particular situation. It indicates that American Psychiatric Association that has 19% of people experience mental illness. Nearly 4.1% of people [ 1 ] are seriously affected by mental illness. In ...
# --------------------------------------------------------------------------------
#
# Result 3:
# DOI: 10.1007/978-3-031-93802-3_7
# Title: Unveiling Power Laws in Graph Mining: Techniques and Applications in Graph Query Analysis
# Publication Date: 2026-01-01
# Content Type: Chapter
# Authors: Adiyattil, Rini, Thangamayan, S., Aswathy Prakash, G.
# Abstract: Power laws play a crucial role in understanding the structural and functional properties of real-world graphs, influencing various aspects of graph mining and query processing. This paper explores the prevalence of power-law distributions in large-scale graph structures and their implications for gr...
# --------------------------------------------------------------------------------
#
# Result 4:
# DOI: 10.1007/978-3-032-02215-8_7
# Title: An Enhanced FP-Growth Algorithm with Hybrid Adaptive Support Threshold for Association Rule Mining
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Saikaew, Kanda Runapongsa, Leung, Carson K., Phiwhorm, Kritbodin
# Abstract: Finding frequent itemsets remains challenging due to manual threshold specification requirements in existing algorithms. This paper presents an Enhanced FP-Growth algorithm incorporating a hybrid adaptive support threshold that combines statistical variance analysis, frequency distribution patterns,...
# --------------------------------------------------------------------------------
#
# Result 5:
# DOI: 10.1007/978-3-031-93257-1_6
# Title: Adaptive Web API Recommendation via Matching Service Clusters and Mashup Requirement
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Zhu, Yue, Zou, Guobing, Yang, Song, Hu, Shengxiang, Li, Pengtao, Zeng, Chunhua
# Abstract: With the rapid proliferation of Web services and Web APIs, recommendation systems can effectively address the issue of information overload and alleviate the burden of meaningless filtering. Existing approaches can help filtering appropriate Web services for mashup creation, however, they often fall...
# --------------------------------------------------------------------------------
#
# Result 6:
# DOI: 10.1007/978-3-032-02088-8_29
# Title: Benchmarking Embedding Techniques for Modeling User Navigation Behavior on Task-Oriented Software
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Boukharouba, Ikram, Sèdes, Florence, Verhaeghe, Benoit, Bortolaso, Christophe
# Abstract: Understanding user navigation patterns from clickstream data is crucial for improving business software, yet remains challenging due to the complexity and variability of real-world environments. Unlike controlled settings, real-world clickstreams are noisy, fragmented, and often incomplete, due to s...
# --------------------------------------------------------------------------------
#
# Result 7:
# DOI: 10.1007/978-3-032-01723-9_9
# Title: Analyzing Water Consumption Patterns in Mexico City: A GIS and Data Science Approach
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Hernández-Vázquez, Israel, Luna-Sánchez, Antonio Jonathan, Hurtado-Perez, Arturo Benjamin, Claramunt, Christophe, Zagal-Flores, Roberto, Mata, Felix
# Abstract: Water scarcity in Mexico City has become an increasingly urgent issue, exacerbated by inefficient and unequal consumption patterns across its urban fabric. This study advances Geographic Information Systems (GIS) research by developing and applying an integrative spatial analysis framework specifica...
# --------------------------------------------------------------------------------
#
# Result 8:
# DOI: 10.1007/978-981-96-6951-6_19
# Title: Research on Sensor Behavioral Psychological Health Based on Multi-task Learning
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Pang, Lulu, Wang, Xianrong, Li, Hua, Wu, Wangyu
# Abstract: As society develops, mental health is becoming increasingly important. Traditional mental health assessment methods, such as face-to-face interviews and observational techniques, are limited by several factors, including subjectivity, response delays, and high costs. To address these issues, recent ...
# --------------------------------------------------------------------------------
#
# Result 9:
# DOI: 10.1007/978-3-031-89518-0_1
# Title: On the Centrality of Web Trackers: Assessing Its Potential for Automated Detection
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Raschke, Philip, Herbke, Patrick, Schwerdtner, Henry
# Abstract: For the past 20 years, web tracking has raised worries among privacy advocates and authorities responsible for data protection. Researchers have proposed several machine learning-driven remedies to identify Web trackers in an automated manner. While those have displayed potential, they have primaril...
# --------------------------------------------------------------------------------
#
# Result 10:
# DOI: 10.1007/978-3-032-02215-8_6
# Title: FNoDe: Faulty Node Detection in Microservices Architecture
# Publication Date: 2026-01-01
# Content Type: Chapter ConferencePaper
# Authors: Borse, Harsh, Satpathy, Utkalika, Mondal, Mainack, Mitra, Bivas
# Abstract: As cloud services shift from monolithic architectures to microservices, post-failure fault and anomaly detection becomes increasingly challenging due to cascading effects across interdependent services and the overwhelming volume of heterogeneous logs and metrics. We propose FNoDe (Faulty Node Detec...
# --------------------------------------------------------------------------------
#
# ✅ Data berhasil disimpan ke: springer_web_usage_mining_20250828_071521.csv
# 📊 Jumlah record yang disimpan: 10
